# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Creating a data frame
result = {'name':          ['Nasir','Asad', 'Fahad','Zeeshan', 'Shan', 'Shoaib', 'Ali', 'Hassan', 'Yasir', 'Junaid'],
          'roll':          [11,22,33,44,55,66,77,88,99,111],
          'python':        [78,67,89,90,91,72,76,89,67,85],
          'excel':         [89,87,67,74,78,90,76,78,90,54],
           'power_bi':     [45,67,89,87,67,90,65,67,56,90],
          'pandas':        [81,85,89,87,41,45,96,56,93,78],
         'machine_learning':[96,95,84,85,82,81,74,75,96,90],
         'statistics':     [67,48,45,98,75,71,70,60,90,93]}
result
# Out:
# {'name': ['Nasir',
#   'Asad',
#   'Fahad',
#   'Zeeshan',
#   'Shan',
#   'Shoaib',
#   'Ali',
#   'Hassan',
#   'Yasir',
#   'Junaid'],
#  'roll': [11, 22, 33, 44, 55, 66, 77, 88, 99, 111],
#  'python': [78, 67, 89, 90, 91, 72, 76, 89, 67, 85],
#  'excel': [89, 87, 67, 74, 78, 90, 76, 78, 90, 54],
#  'power_bi': [45, 67, 89, 87, 67, 90, 65, 67, 56, 90],
#  'pandas': [81, 85, 89, 87, 41, 45, 96, 56, 93, 78],
#  'machine_learning': [96, 95, 84, 85, 82, 81, 74, 75, 96, 90],
#  'statistics': [67, 48, 45, 98, 75, 71, 70, 60, 90, 93]}

# %%
df = pd.DataFrame(result)
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     89        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     74        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        56      93                96
# 9   Junaid   111      85     54        90      78                90
#
#    statistics
# 0          67
# 1          48
# 2          45
# 3          98
# 4          75
# 5          71
# 6          70
# 7          60
# 8          90
# 9          93

# %%
df['Total'] = 600

# %%
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     89        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     74        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        56      93                96
# 9   Junaid   111      85     54        90      78                90
#
#    statistics  Total
# 0          67    600
# 1          48    600
# 2          45    600
# 3          98    600
# 4          75    600
# 5          71    600
# 6          70    600
# 7          60    600
# ...

# %%
df['Obtained'] = df.python+df.excel+df.power_bi+df.pandas+df.machine_learning+df.statistics

# %%
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     89        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     74        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        56      93                96
# 9   Junaid   111      85     54        90      78                90
#
#    statistics  Total  Obtained
# 0          67    600       456
# 1          48    600       449
# 2          45    600       463
# 3          98    600       521
# 4          75    600       434
# ...

# %%
df['Percentage'] = round(df.Obtained/df.Total*100, 1)
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     89        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     74        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        56      93                96
# 9   Junaid   111      85     54        90      78                90
#
#    statistics  Total  Obtained  Percentage
# 0          67    600       456        76.0
# 1          48    600       449        74.8
# 2          45    600       463        77.2
# 3          98    600       521        86.8
# ...

# %%
df['Grade'] =['A*' if per>=90 else "A" if per>=80 else 'B' if per>=70 else 'C' if per>=60 else 'D' if per >=50 else "F" for per in df.Percentage ]

# %%
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     89        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     74        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        56      93                96
# 9   Junaid   111      85     54        90      78                90
#
#    statistics  Total  Obtained  Percentage Grade
# 0          67    600       456        76.0     B
# 1          48    600       449        74.8     B
# 2          45    600       463        77.2     B
# ...

# %%
allmarks = list(zip(df.python, df.excel, df.power_bi, df.pandas , df.machine_learning, df.statistics))

# %%
df['status'] = ["Fail" if p<50 else
                "Fail" if e<50 else
                "Fail" if pb<50 else
                "Fail" if p<50 else
                "Fail" if ml<50 else
                "Fail" if st<50 else
                "Pass"
                for p,e,pb,p,ml,st in allmarks ]

# %%
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     89        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     74        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        56      93                96
# 9   Junaid   111      85     54        90      78                90
#
#    statistics  Total  Obtained  Percentage Grade status
# 0          67    600       456        76.0     B   Fail
# 1          48    600       449        74.8     B   Fail
# ...

# %%
import pandas as pd

# %%
cardata = pd.read_csv("data files/car_data.csv")

# %%
cardata
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
bollywood = pd.read_excel("data files/bollywood.xlsx")

# %%
bollywood
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
cardata = pd.read_csv("data files/car_data.csv")
cardata
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
url1 = 'https://raw.githubusercontent.com/FBosler/Medium-Data-Exploration/master/order_leads.csv'
url2 = 'https://raw.githubusercontent.com/FBosler/Medium-Data-Exploration/master/sales_team.csv'

# %%
orders = pd.read_csv(url1)

# %%
orders
# Out:
#                Order Id        Company Id                    Company Name  \
# 0      HZSXLI1IS9RGABZW  D0AUXPP07H6AVSGD          Melancholy Social-Role
# 1      582WPS3OW8T6YT0R  D0AUXPP07H6AVSGD          Melancholy Social-Role
# 2      KRF65MQZBOYG4Y9T  D0AUXPP07H6AVSGD          Melancholy Social-Role
# 3      N3EDZ5V1WGSWW828  D0AUXPP07H6AVSGD          Melancholy Social-Role
# 4      QXBC8COXEXGFSPLP  D0AUXPP07H6AVSGD          Melancholy Social-Role
# ...                 ...               ...                             ...
# 99995  HKZFX556ZQRZJZWR  APH243SK72T90MPS  Trade-Preparatory Quarterbacks
# 99996  962CSDMAJ49E0CRK  APH243SK72T90MPS  Trade-Preparatory Quarterbacks
# 99997  ZW7RO9TLL6EVVJEC  APH243SK72T90MPS  Trade-Preparatory Quarterbacks
# 99998  LNKGIWMZ9RT49IE9  APH243SK72T90MPS  Trade-Preparatory Quarterbacks
# 99999  X9Y21H4JWX6OGC2Z  APH243SK72T90MPS  Trade-Preparatory Quarterbacks
#
#              Date  Order Value  Converted
# ...

# %%
order2 = pd.read_csv(url2)

# %%
order2
# Out:
#            Sales Rep      Sales Rep Id                    Company Name  \
# 0     William Taylor  ZTZA0ZLYZR85PTUJ          Melancholy Social-Role
# 1     William Taylor  ZTZA0ZLYZR85PTUJ                  Pee-Wee Pigeon
# 2     William Taylor  ZTZA0ZLYZR85PTUJ             Vaginal 36-Year-Old
# 3     William Taylor  ZTZA0ZLYZR85PTUJ            Unhurried Musician'S
# 4     William Taylor  ZTZA0ZLYZR85PTUJ             Comprehensive Lists
# ...              ...               ...                             ...
# 4614    Ida Woodward  LF3CPWWZKSNB1AXI          Unauthorized Increases
# 4615    Ida Woodward  LF3CPWWZKSNB1AXI             Atom-Like Principle
# 4616    Ida Woodward  LF3CPWWZKSNB1AXI        Congratulatory Economist
# 4617    Ida Woodward  LF3CPWWZKSNB1AXI                 Readable Pilots
# 4618    Ida Woodward  LF3CPWWZKSNB1AXI  Trade-Preparatory Quarterbacks
#
#             Company Id
# 0     D0AUXPP07H6AVSGD
# 1     TJW99R4RWH02INII
# 2     3S20IO1O1DYXMUNU
# ...

# %% [markdown]
# # Handling missing values

# %%
movies = pd.read_csv('data files/imdb-top-1000.csv')

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
movies.isna()
# Out:
#      Series_Title  Released_Year  Runtime  Genre  IMDB_Rating  Director  \
# 0           False          False    False  False        False     False
# 1           False          False    False  False        False     False
# 2           False          False    False  False        False     False
# 3           False          False    False  False        False     False
# 4           False          False    False  False        False     False
# ..            ...            ...      ...    ...          ...       ...
# 995         False          False    False  False        False     False
# 996         False          False    False  False        False     False
# 997         False          False    False  False        False     False
# 998         False          False    False  False        False     False
# 999         False          False    False  False        False     False
#
#      Star1  No_of_Votes  Gross  Metascore
# 0    False        False  False      False
# ...

# %%
movies.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Director           0
# Star1              0
# No_of_Votes        0
# Gross              0
# Metascore        157
# dtype: int64

# %%
movies[movies['Metascore'].isna()]
# Out:
#                       Series_Title Released_Year  Runtime      Genre  \
# 20                 Soorarai Pottru          2020      153      Drama
# 54       Ayla: The Daughter of War          2017      125  Biography
# 55                    Vikram Vedha          2017      147     Action
# 57                          Dangal          2016      161     Action
# 65                Taare Zameen Par          2007      165      Drama
# ..                             ...           ...      ...        ...
# 872  The Day the Earth Stood Still          1951       92      Drama
# 874                          Gilda          1946      110      Drama
# 899                      El cuerpo          2012      112    Mystery
# 909                      Celda 211          2009      113     Action
# 913                      Die Welle          2008      107      Drama
#
#      IMDB_Rating       Director           Star1  No_of_Votes        Gross  \
# ...

# %%
movies[movies.Metascore.isnull()]
# Out:
#                       Series_Title Released_Year  Runtime      Genre  \
# 20                 Soorarai Pottru          2020      153      Drama
# 54       Ayla: The Daughter of War          2017      125  Biography
# 55                    Vikram Vedha          2017      147     Action
# 57                          Dangal          2016      161     Action
# 65                Taare Zameen Par          2007      165      Drama
# ..                             ...           ...      ...        ...
# 872  The Day the Earth Stood Still          1951       92      Drama
# 874                          Gilda          1946      110      Drama
# 899                      El cuerpo          2012      112    Mystery
# 909                      Celda 211          2009      113     Action
# 913                      Die Welle          2008      107      Drama
#
#      IMDB_Rating       Director           Star1  No_of_Votes        Gross  \
# ...

# %%
droppedna = movies.dropna()

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
dropedna
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 dropedna
#
# NameError: name 'dropedna' is not defined

# %%
droppedna
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
orders.isna().sum()
# Out:
# Order Id        0
# Company Id      0
# Company Name    0
# Date            0
# Order Value     0
# Converted       0
# dtype: int64

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
movies.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Director           0
# Star1              0
# No_of_Votes        0
# Gross              0
# Metascore        157
# dtype: int64

# %%
movies.loc[1:3] = np.nan

# %%
movies
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994    142.0   Drama          9.3
# 1                         NaN           NaN      NaN     NaN          NaN
# 2                         NaN           NaN      NaN     NaN          NaN
# 3                         NaN           NaN      NaN     NaN          NaN
# 4                12 Angry Men          1957     96.0   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961    115.0  Comedy          7.6
# 996                     Giant          1956    201.0   Drama          7.6
# 997     From Here to Eternity          1953    118.0   Drama          7.6
# 998                  Lifeboat          1944     97.0   Drama          7.6
# 999              The 39 Steps          1935     86.0   Crime          7.6
#
#              Director              Star1  No_of_Votes        Gross  Metascore
# ...

# %%
movies.fillna(method="bfill")
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994    142.0   Drama          9.3
# 1                12 Angry Men          1957     96.0   Crime          9.0
# 2                12 Angry Men          1957     96.0   Crime          9.0
# 3                12 Angry Men          1957     96.0   Crime          9.0
# 4                12 Angry Men          1957     96.0   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961    115.0  Comedy          7.6
# 996                     Giant          1956    201.0   Drama          7.6
# 997     From Here to Eternity          1953    118.0   Drama          7.6
# 998                  Lifeboat          1944     97.0   Drama          7.6
# 999              The 39 Steps          1935     86.0   Crime          7.6
#
#              Director              Star1  No_of_Votes        Gross  Metascore
# ...

# %%
result
# Out:
# {'name': ['Nasir',
#   'Asad',
#   'Fahad',
#   'Zeeshan',
#   'Shan',
#   'Shoaib',
#   'Ali',
#   'Hassan',
#   'Yasir',
#   'Junaid'],
#  'roll': [11, 22, 33, 44, 55, 66, 77, 88, 99, 111],
#  'python': [78, 67, 89, 90, 91, 72, 76, 89, 67, 85],
#  'excel': [89, 87, 67, 74, 78, 90, 76, 78, 90, 54],
#  'power_bi': [45, 67, 89, 87, 67, 90, 65, 67, 56, 90],
#  'pandas': [81, 85, 89, 87, 41, 45, 96, 56, 93, 78],
#  'machine_learning': [96, 95, 84, 85, 82, 81, 74, 75, 96, 90],
#  'statistics': [67, 48, 45, 98, 75, 71, 70, 60, 90, 93]}

# %%
df
# Out:
#       name  roll  python  excel  power_bi  pandas  machine_learning  \
# 0    Nasir    11      78     89        45      81                96
# 1     Asad    22      67     87        67      85                95
# 2    Fahad    33      89     67        89      89                84
# 3  Zeeshan    44      90     74        87      87                85
# 4     Shan    55      91     78        67      41                82
# 5   Shoaib    66      72     90        90      45                81
# 6      Ali    77      76     76        65      96                74
# 7   Hassan    88      89     78        67      56                75
# 8    Yasir    99      67     90        56      93                96
# 9   Junaid   111      85     54        90      78                90
#
#    statistics  Total  Obtained  Percentage Grade status
# 0          67    600       456        76.0     B   Fail
# 1          48    600       449        74.8     B   Fail
# ...

# %%
sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 sales
#
# NameError: name 'sales' is not defined

# %%
sales = pd.read_excel('data files/SaleData.xlsx')

# %%
sales
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
dup = sales.loc[[31,20,22] , : ]

# %%
new_sales = pd.concat([sales,dup])

# %%
new_sales
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
new_sales.reset_index(drop="True",inplace =True)

# %%
new_sales
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
new_sales_filtered = new_sales[~(new_sales.duplicated())]

# %%
new_sales
# Out:
#     OrderDate   Region  Manager   SalesMan          Item   Units  Unit_price  \
# 0  2018-01-06     East   Martha  Alexander    Television   95.00    1198.000
# 1  2018-01-23  Central  Hermann     Shelli  Home Theater   50.00     500.000
# 2  2018-02-09  Central  Hermann       Luis    Television   36.00    1198.000
# 3  2018-02-26  Central  Timothy      David    Cell Phone   27.00     225.000
# 4  2018-03-15     West  Timothy    Stephen    Television   56.00    1198.000
# 5  2018-04-01     East   Martha  Alexander  Home Theater   60.00     500.000
# 6  2018-04-18  Central   Martha     Steven    Television   75.00    1198.000
# 7  2018-05-05  Central  Hermann       Luis    Television   90.00    1198.000
# 8  2018-05-22     West  Douglas    Michael    Television   32.00    1198.000
# 9  2018-06-08     East   Martha  Alexander  Home Theater   60.00     500.000
# 10 2018-06-25  Central  Hermann      Sigal    Television   90.00    1198.000
# ...

# %%
car_data = pd.read_csv("data files/car_data.csv")

# %%
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
car_data
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
car_data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
#car_data[car_data.kms_driven.isna()[5]] = 0

# %%
#car_data[car_data.kms_driven.isna()]
# Out:
#                                        name     company  year          Price  \
# 69          I want to sell my car Tata Zest           I  2017  Ask For Price
# 85          I want to sell my car Tata Zest           I  2017  Ask For Price
# 185  Commercial , DZire LDI, 2016, for sale  Commercial   ...  Ask For Price
# 195                 Tata indigo ecs LX, 201        Tata  150k       1,50,000
# 206                      MARUTI SUZUKI DESI      MARUTI  TOUR       4,00,000
# 286  Commercial , DZire LDI, 2016, for sale  Commercial   ...  Ask For Price
# 294                                    Yama      Yamaha  r 15         55,000
# 360                          selling car Ta     selling  Zest  Ask For Price
# 368                            Tata Zest 90        Tata  /-Rs  Ask For Price
# 385           Maruti Suzuki Swift Dzire car      Maruti  sale       3,00,000
# 395     Maruti Suzuki Swift Dzire Tour (Gat      Maruti  ara)       3,00,000
# ...

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
#  6   False       892 non-null    int64
# dtypes: int64(1), object(6)
# memory usage: 48.9+ KB

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car_data.shape
# Out:
# (892, 6)

# %%
car_data.head() #by default brings the first five record
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car_data.tail() #retrieves the last five records
# Out:
#                           name    company  year     Price  kms_driven  \
# 887                         Ta       Tara  zest  3,10,000         NaN
# 888        Tata Zest XM Diesel       Tata  2018  2,60,000  27,000 kms
# 889         Mahindra Quanto C8   Mahindra  2013  3,90,000  40,000 kms
# 890   Honda Amaze 1.2 E i VTEC      Honda  2014  1,80,000      Petrol
# 891  Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  1,60,000      Petrol
#
#     fuel_type
# 887       NaN
# 888    Diesel
# 889    Diesel
# 890       NaN
# 891       NaN

# %%
car_data.sample(2) #retrieves random record
# Out:
#                                          name   company  year      Price  \
# 182                               Hyundai i20   Hyundai  2009   1,99,000
# 434  Mercedes Benz A Class A 180 Sport Petrol  Mercedes  2013  15,00,000
#
#      kms_driven fuel_type
# 182  31,000 kms    Petrol
# 434  14,000 kms    Petrol

# %%
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car_data.isna()
# Out:
#       name  company   year  Price  kms_driven  fuel_type
# 0    False    False  False  False       False      False
# 1    False    False  False  False       False      False
# 2    False    False  False  False       False      False
# 3    False    False  False  False       False      False
# 4    False    False  False  False       False      False
# ..     ...      ...    ...    ...         ...        ...
# 887  False    False  False  False        True       True
# 888  False    False  False  False       False      False
# 889  False    False  False  False       False      False
# 890  False    False  False  False       False       True
# 891  False    False  False  False       False       True
#
# [892 rows x 6 columns]

# %%
car_data.isnull()
# Out:
#       name  company   year  Price  kms_driven  fuel_type
# 0    False    False  False  False       False      False
# 1    False    False  False  False       False      False
# 2    False    False  False  False       False      False
# 3    False    False  False  False       False      False
# 4    False    False  False  False       False      False
# ..     ...      ...    ...    ...         ...        ...
# 887  False    False  False  False        True       True
# 888  False    False  False  False       False      False
# 889  False    False  False  False       False      False
# 890  False    False  False  False       False       True
# 891  False    False  False  False       False       True
#
# [892 rows x 6 columns]

# %%
car_data.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
car_data.notnull().sum()
# Out:
# name          892
# company       892
# year          892
# Price         892
# kms_driven    840
# fuel_type     837
# dtype: int64

# %%
car_data[~(car_data.isna())]
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
car_data.dropna(inplace=True)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 837 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        837 non-null    object
#  1   company     837 non-null    object
#  2   year        837 non-null    object
#  3   Price       837 non-null    object
#  4   kms_driven  837 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 45.8+ KB

# %%
#duplicate records
car_data.duplicated().sum()
# Out:
# 92

# %%
car_data.drop_duplicates(inplace=True)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 745 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        745 non-null    object
#  1   company     745 non-null    object
#  2   year        745 non-null    object
#  3   Price       745 non-null    object
#  4   kms_driven  745 non-null    object
#  5   fuel_type   745 non-null    object
# dtypes: object(6)
# memory usage: 40.7+ KB

# %%
car_data
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
car_data.set_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[334], line 1
# ----> 1 car_data.set_index()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.set_index() missing 1 required positional argument: 'keys'

# %%
car_data.name.unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
car_data.name.str.split().str[:3].str.join(sep=" ")
# Out:
# 0         Hyundai Santro Xing
# 1         Mahindra Jeep CL550
# 2          Maruti Suzuki Alto
# 3           Hyundai Grand i10
# 4      Ford EcoSport Titanium
#                 ...
# 883        Maruti Suzuki Ritz
# 885            Tata Indica V2
# 886      Toyota Corolla Altis
# 888              Tata Zest XM
# 889        Mahindra Quanto C8
# Name: name, Length: 745, dtype: object

# %%
car_data['name'] = car_data.name.str.split().str[:3].str.join(sep=" ")

# %%
car_data.name
# Out:
# 0         Hyundai Santro Xing
# 1         Mahindra Jeep CL550
# 2          Maruti Suzuki Alto
# 3           Hyundai Grand i10
# 4      Ford EcoSport Titanium
#                 ...
# 883        Maruti Suzuki Ritz
# 885            Tata Indica V2
# 886      Toyota Corolla Altis
# 888              Tata Zest XM
# 889        Mahindra Quanto C8
# Name: name, Length: 745, dtype: object

# %%
car_data.sample(10)
# Out:
#                          name     company  year     Price  kms_driven  \
# 513            Honda City 1.5       Honda  2014  4,99,000  22,000 kms
# 775            Tata Indica V2        Tata  2012  1,15,000  64,000 kms
# 236               Datsun GO T      Datsun  2016  2,45,000   7,000 kms
# 675             Honda City SV       Honda  2014  4,75,000  34,000 kms
# 881               Skoda Fabia       Skoda  2009  1,10,000  45,000 kms
# 682       Maruti Suzuki Swift      Maruti  2017  6,50,000  41,800 kms
# 66   Volkswagen Polo Highline  Volkswagen  2014  3,15,000  60,000 kms
# 665     Chevrolet Beat Diesel   Chevrolet  2016  1,79,999  19,336 kms
# 164        Hyundai i10 Sportz     Hyundai  2010  1,68,000  45,872 kms
# 659         Maruti Suzuki Zen      Maruti  2008  1,25,000  46,000 kms
#
#     fuel_type
# 513    Petrol
# 775    Diesel
# 236    Petrol
# 675    Diesel
# 881    Petrol
# 682    Diesel
# 66     Petrol
# 665    Diesel
# 164    Petrol
# 659    Petrol

# %%
car_data.company
# Out:
# 0       Hyundai
# 1      Mahindra
# 2        Maruti
# 3       Hyundai
# 4          Ford
#          ...
# 883      Maruti
# 885        Tata
# 886      Toyota
# 888        Tata
# 889    Mahindra
# Name: company, Length: 745, dtype: object

# %%
car_data.year
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 883    2011
# 885    2009
# 886    2009
# 888    2018
# 889    2013
# Name: year, Length: 745, dtype: object

# %%
car_data.year = pd.to_datetime(car_data.year)

# %%
car_data.Price.unique
# Out:
# <bound method Series.unique of 0             80,000
# 1           4,25,000
# 2      Ask For Price
# 3           3,25,000
# 4           5,75,000
#            ...
# 883         2,70,000
# 885         1,10,000
# 886         3,00,000
# 888         2,60,000
# 889         3,90,000
# Name: Price, Length: 745, dtype: object>

# %%
(car_data.Price == 'Ask For Price').sum()
# Out:
# 21

# %%
car_data.Price.value_counts()
# Out:
# Ask For Price    21
# 2,50,000         13
# 1,30,000         11
# 3,50,000         11
# 4,00,000         10
#                  ..
# 7,70,000          1
# 3,35,000          1
# 6,35,000          1
# 65,000            1
# 5,00,001          1
# Name: Price, Length: 273, dtype: int64

# %%
car_data = car_data[car_data.Price != 'Ask For Price']

# %%
car_data.Price.unique()
# Out:
# array(['80,000', '4,25,000', '3,25,000', '5,75,000', '1,75,000',
#        '1,90,000', '8,30,000', '2,50,000', '1,82,000', '3,15,000',
#        '4,15,000', '3,20,000', '10,00,000', '5,00,000', '3,50,000',
#        '1,60,000', '3,10,000', '75,000', '1,00,000', '2,90,000', '95,000',
#        '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000',
#        '85,000', '2,00,000', '5,70,000', '1,10,000', '4,48,999',
#        '18,91,111', '1,59,500', '3,44,999', '4,49,999', '8,65,000',
#        '6,99,000', '3,75,000', '2,24,999', '12,00,000', '1,95,000',
#        '3,51,000', '2,40,000', '90,000', '1,55,000', '6,00,000',
#        '1,89,500', '2,10,000', '3,90,000', '1,35,000', '16,00,000',
#        '7,01,000', '2,65,000', '5,25,000', '3,72,000', '6,35,000',
# ...

# %%
car_data.Price = car_data.Price.str.replace(',','').astype('int32')
# Out:
# C:\Users\Arifa Mustafa\AppData\Local\Temp\ipykernel_10260\3080782287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_data.Price = car_data.Price.str.replace(',','').astype('int32')

# %%
car_data.Price
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 883    270000
# 885    110000
# 886    300000
# 888    260000
# 889    390000
# Name: Price, Length: 724, dtype: int32

# %%
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
car_data.kms_driven = car_data.kms_driven.str.replace(',','').str.replace(' kms','')
# Out:
# C:\Users\Arifa Mustafa\AppData\Local\Temp\ipykernel_10260\598328710.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_data.kms_driven = car_data.kms_driven.str.replace(',','').str.replace(' kms','')

# %%
car_data.kms_driven
# Out:
# 0       45000
# 1          40
# 3       28000
# 4       36000
# 6       41000
#         ...
# 883     50000
# 885     30000
# 886    132000
# 888     27000
# 889     40000
# Name: kms_driven, Length: 724, dtype: object

# %%
car_data
# Out:
#                        name   company       year   Price kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000         40    Diesel
# 3         Hyundai Grand i10   Hyundai 2014-01-01  325000      28000    Petrol
# 4    Ford EcoSport Titanium      Ford 2014-01-01  575000      36000    Diesel
# 6                 Ford Figo      Ford 2012-01-01  175000      41000    Diesel
# ..                      ...       ...        ...     ...        ...       ...
# 883      Maruti Suzuki Ritz    Maruti 2011-01-01  270000      50000    Petrol
# 885          Tata Indica V2      Tata 2009-01-01  110000      30000    Diesel
# 886    Toyota Corolla Altis    Toyota 2009-01-01  300000     132000    Petrol
# 888            Tata Zest XM      Tata 2018-01-01  260000      27000    Diesel
# 889      Mahindra Quanto C8  Mahindra 2013-01-01  390000      40000    Diesel
#
# [724 rows x 6 columns]

# %%
car_data.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', 'LPG'], dtype=object)

# %%
car_data.reset_index(drop=True,inplace=True)

# %%
car_data
# Out:
#                        name   company       year   Price kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000         40    Diesel
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000      28000    Petrol
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000      36000    Diesel
# 4                 Ford Figo      Ford 2012-01-01  175000      41000    Diesel
# ..                      ...       ...        ...     ...        ...       ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000      50000    Petrol
# 720          Tata Indica V2      Tata 2009-01-01  110000      30000    Diesel
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000     132000    Petrol
# 722            Tata Zest XM      Tata 2018-01-01  260000      27000    Diesel
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000      40000    Diesel
#
# [724 rows x 6 columns]

# %%
car_data.to_csv('data files/clearned-car_data.csv')

# %%
car_data.to_html('data files/cleaned-car_data.html')

# %%
#which is the most expensive and cheap car
car_data[car_data.Price == car_data.Price.max()]['name'].values[0]
# Out:
# 'Mahindra XUV500 W6'

# %%
sasti_car1,sasti_car2 = car_data[car_data.Price == car_data.Price.min()]['name'].values

# %%
sasti_car1
# Out:
# 'Maruti Suzuki Maruti'

# %%
sasti_car2
# Out:
# 'Maruti Suzuki 800'

# %%
#which brand is most demanding
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
#top three popular company
car_data.company.value_counts()[:3]
# Out:
# Maruti      202
# Hyundai     129
# Mahindra     78
# Name: company, dtype: int64

# %%
car_data.company.value_counts().head(3)
# Out:
# Maruti      202
# Hyundai     129
# Mahindra     78
# Name: company, dtype: int64

# %%
#least demanding company
car_data.company.value_counts(ascending=True)[:3]
# Out:
# Volvo    1
# Land     1
# Jeep     1
# Name: company, dtype: int64

# %%
#least demanding company
company1,company2,company3 = car_data.company.value_counts(ascending=True)[:3].index

# %%
company1
# Out:
# 'Volvo'

# %%
company2
# Out:
# 'Land'

# %%
company3
# Out:
# 'Jeep'

# %% [markdown]
# # Apply method

# %%
#lambda function
int(car_data.Price.mean())
# Out:
# 403245

# %%
car_data.Price.max()
# Out:
# 8500003

# %%
car_data.Price.min()
# Out:
# 30000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(car_data.name,car_data.Price)

# %%
def category(price):
    if price > car_data.Price.median():
        return "Expensive"
    else:
        return "Affordable"

# %%
car_data['category'] = car_data.Price.apply(category)
# Out:
# C:\Users\Arifa Mustafa\AppData\Local\Temp\ipykernel_10260\3165204944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_data['category'] = car_data.Price.apply(category)

# %%
car_data
# Out:
#                        name   company       year   Price kms_driven fuel_type  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000         40    Diesel
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000      28000    Petrol
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000      36000    Diesel
# 4                 Ford Figo      Ford 2012-01-01  175000      41000    Diesel
# ..                      ...       ...        ...     ...        ...       ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000      50000    Petrol
# 720          Tata Indica V2      Tata 2009-01-01  110000      30000    Diesel
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000     132000    Petrol
# 722            Tata Zest XM      Tata 2018-01-01  260000      27000    Diesel
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000      40000    Diesel
#
#        category
# ...

# %%
car_data['Category'] = car_data.Price.apply(lambda p: "Expensive" if p>car_data.Price.median() else "Cheap")
# Out:
# C:\Users\Arifa Mustafa\AppData\Local\Temp\ipykernel_10260\3283304304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_data['Category'] = car_data.Price.apply(lambda p: "Expensive" if p>car_data.Price.median() else "Cheap")

# %%
car_data
# Out:
#                        name   company       year   Price kms_driven fuel_type  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000         40    Diesel
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000      28000    Petrol
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000      36000    Diesel
# 4                 Ford Figo      Ford 2012-01-01  175000      41000    Diesel
# ..                      ...       ...        ...     ...        ...       ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000      50000    Petrol
# 720          Tata Indica V2      Tata 2009-01-01  110000      30000    Diesel
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000     132000    Petrol
# 722            Tata Zest XM      Tata 2018-01-01  260000      27000    Diesel
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000      40000    Diesel
#
#        category   Category
# ...

# %%
car_data.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type',
#        'category', 'Category'],
#       dtype='object')

# %%
del car_data['Category']

# %%
car_data
# Out:
#                        name   company       year   Price kms_driven fuel_type  \
# 0       Hyundai Santro Xing   Hyundai 2007-01-01   80000      45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra 2006-01-01  425000         40    Diesel
# 2         Hyundai Grand i10   Hyundai 2014-01-01  325000      28000    Petrol
# 3    Ford EcoSport Titanium      Ford 2014-01-01  575000      36000    Diesel
# 4                 Ford Figo      Ford 2012-01-01  175000      41000    Diesel
# ..                      ...       ...        ...     ...        ...       ...
# 719      Maruti Suzuki Ritz    Maruti 2011-01-01  270000      50000    Petrol
# 720          Tata Indica V2      Tata 2009-01-01  110000      30000    Diesel
# 721    Toyota Corolla Altis    Toyota 2009-01-01  300000     132000    Petrol
# 722            Tata Zest XM      Tata 2018-01-01  260000      27000    Diesel
# 723      Mahindra Quanto C8  Mahindra 2013-01-01  390000      40000    Diesel
#
#        category
# ...

# %% [markdown]
# # Data Wrangling

# %%
sheet0 = pd.read_excel('data files/test_data.xlsx',sheet_name=0)
sheet1 = pd.read_excel('data files/test_data.xlsx',sheet_name=1)
sheet2 = pd.read_excel('data files/test_data.xlsx',sheet_name=2)

# %%
sheet0.shape
# Out:
# (9, 5)

# %%
sheet1.shape
# Out:
# (9, 5)

# %%
sheet2.shape
# Out:
# (9, 4)

# %%
newframe = pd.concat([sheet0,sheet1])

# %%
newframe.reset_index(drop=True,inplace=True)

# %%
newframe
# Out:
#     sales_man_id sales_man_name sales_man_city  product_id manager
# 0              1           Asad        Karachi         123   Jawed
# 1              2         Sumair         Lahore         123   Jawed
# 2              3         Farjad        Karachi         145   Najam
# 3              4         Hassan         Lahore         567   Najam
# 4              5          Nasir      Hyderabad         234   Jawed
# 5              6         Kashif      Hyderabad         234  Faisal
# 6              7           Sana         Lahore         567  Faisal
# 7              8         Fatima        Karachi         345   Najam
# 8              9       Abdullah        Karachi         123  Faisal
# 9             11          Ahmed        Karachi         123   Jawed
# 10            22           Umer         Lahore         123   Jawed
# 11            33        Huzaifa        Karachi         145   Najam
# 12            44           Asad         Lahore         567   Najam
# ...

# %%
pd.concat([sheet2,newframe])
# Out:
#    sales_man_name Region   Sales   Amount   sales_man_id sales_man_city  \
# 0            Asad       A  100.0  100000.0           NaN            NaN
# 1         Hussain       B  300.0  450000.0           NaN            NaN
# 2             Ali       C  234.0  125000.0           NaN            NaN
# 3            Sana       D  231.0  652000.0           NaN            NaN
# 4         Fatima        E  324.0  145000.0           NaN            NaN
# 5          Kashif       F  123.0  825000.0           NaN            NaN
# 6          Hassan       G  129.0  125000.0           NaN            NaN
# 7           Almas       H  345.0  325600.0           NaN            NaN
# 8           Fahan       I  400.0  895200.0           NaN            NaN
# 0            Asad     NaN    NaN       NaN           1.0        Karachi
# 1          Sumair     NaN    NaN       NaN           2.0         Lahore
# 2          Farjad     NaN    NaN       NaN           3.0        Karachi
# ...

# %%
sheet1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
sheet0
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
sheet0.merge(sheet1,on="sales_man_city")
# Out:
#     sales_man_id_x sales_man_name_x sales_man_city  product_id_x manager_x  \
# 0                1             Asad        Karachi           123     Jawed
# 1                1             Asad        Karachi           123     Jawed
# 2                1             Asad        Karachi           123     Jawed
# 3                1             Asad        Karachi           123     Jawed
# 4                3           Farjad        Karachi           145     Najam
# 5                3           Farjad        Karachi           145     Najam
# 6                3           Farjad        Karachi           145     Najam
# 7                3           Farjad        Karachi           145     Najam
# 8                8           Fatima        Karachi           345     Najam
# 9                8           Fatima        Karachi           345     Najam
# 10               8           Fatima        Karachi           345     Najam
# ...

# %%
sheet0.merge(sheet1)
# Out:
# Empty DataFrame
# Columns: [sales_man_id, sales_man_name, sales_man_city, product_id, manager]
# Index: []

# %%
sheet0.merge(sheet1,on='sales_man_id')
# Out:
# Empty DataFrame
# Columns: [sales_man_id, sales_man_name_x, sales_man_city_x, product_id_x, manager_x, sales_man_name_y, sales_man_city_y, product_id_y, manager_y]
# Index: []

# %%
sheet0.columns = ['Sales_man_id', 'Sales_man_name', 'Sales_man_city', 'Product_id',
       'Manager']

# %%
sheet0.merge(sheet1,left_on="Sales_man_id",right_on="sales_man_id")
# Out:
# Empty DataFrame
# Columns: [Sales_man_id, Sales_man_name, Sales_man_city, Product_id, Manager, sales_man_id, sales_man_name, sales_man_city, product_id, manager]
# Index: []

# %% [markdown]
# # Data Stripping

# %%
#sometimes values doesnot equate due to the spaces arount. to remove the spaces we use strip
sheet0.Sales_man_name = sheet0.Sales_man_name.apply(lambda name: name.strip())
